# %% [markdown]
# Tool（自習！）: https://python.langchain.com/docs/how_to/#tools

# %% [markdown]
# https://python.langchain.com/docs/how_to/custom_tools/

# %% [markdown]
# ![image.png](attachment:image.png)
